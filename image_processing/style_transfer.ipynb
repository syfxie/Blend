# %% [markdown]
# ## Import Dependencies

# %%
import os
import copy

from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms

# %% [markdown]
# ## Set Up

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' # GPU can accomodate greater image sizes and faster image synthesis

# %% [markdown]
# ## Load and Process Images

# %%
image_dir = "./static"

# %%
def load_image(image_path, size=(128, 128)): # using default size for CPU
    image = Image.open(image_path)
    
    loader = transforms.Compose([
        transforms.Resize(size),  # resize
        transforms.ToTensor()])  # transform image into tensor

    image = loader(image).unsqueeze(0) # models in torch.nn requires inputs with a batch dimension
    return image.to(device, torch.float)


def show_image(tensor, title=None):
    image = tensor.cpu().clone()  # clone the tensor to avoid modifying the original
    
    if image.dim() == 4:
        image = image.squeeze(0) # remove artificial batch dimension
    
    image = transforms.ToPILImage()(image)
    plt.imshow(image)

    if title:
        plt.title(title)
    plt.pause(0.01)

# %%
image_size = (128, 128)
content_image = load_image(os.path.join(image_dir, "content_image.jpeg"), image_size)
style_image = load_image(os.path.join(image_dir, "style_reference.jpeg"), image_size)

print('content image shape: ', content_image.size())
print('style image shape: ', style_image.size())
# Out:
# content image shape:  torch.Size([1, 3, 128, 128])
# style image shape:  torch.Size([1, 3, 128, 128])

# %%
show_image(content_image, "Content Image")
show_image(style_image, "Style Image")

# %% [markdown]
# ## Gram Matrix

# %%
# A Gram matrix is the result of multiplying a matrix by its transpose.
# Since our inputs will by pytorch tensors, we first need to manipulate the shape of the tensor to become a 2D matrix
# before performing matrix multiplication.

# Since the style features of an image are in the higher layers of the network, 
# the resulting matrix must be normalized to reduce influence of the first layers during gradient descent.


def gram_matrix(input):
    '''
    Computes the Gram matrix of a tensor.
    '''
    print("calculating gram matrix...")

    if input.dim() == 3:
        input = input.unsqueeze(0)  # input must have an artificial batch dimension

    shape = input.size()
    # print("input shape: ", shape)

    try:
        reshaped = input.view(shape[0] * shape[1], shape[2] * shape[3])  # flatten tensor into 2D
        # print("flattened tensor shape: ", reshaped.size())
        
        # multiply matrix by its transpose to compute the gram product
        result = torch.mm(reshaped, reshaped.t())

        # normalize the matrix to scale each value within 0-1
        result = result.div(shape[0] * shape[1] * shape[2] * shape[3])

        # print("Normalized matrix shape: ", result.size())
        return result

    except IndexError:
        print("Input tensor must have 4 dimensions. Received {}D tensor instead".format(len(shape)))

# %%
test_res = gram_matrix(style_image)
# Out:
# calculating gram matrix...

# %% [markdown]
# ### Style Loss

# %%
# create the style and content loss as modules to add them into the model

class StyleLoss(nn.Module):
    
    def __init__(self, target):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target).detach()  # the target must be detached to compute the gradient since it needs to be a static value

    def forward(self, input):  # defines the computation (forward propagation) the module performs on the input
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

    # back propagation method is defined automatically

# %% [markdown]
# ### Content Loss

# %%
class ContentLoss(nn.Module):

    def __init__(self, target):
        super(ContentLoss, self).__init__()
        self.target = target.detach()

    def forward(self, input):
    
        self.loss = F.mse_loss(input, self.target)
        return input

# %% [markdown]
# ## Normalization

# %% [markdown]
# "All pre-trained models expect input images normalized in the same way, i.e. mini-batches of 3-channel RGB images of shape (3 x H x W), where H and W are expected to be at least 224. The images have to be loaded in to a range of [0, 1] and then normalized using mean = [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225]" (https://pytorch.org/vision/0.8/models.html)

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# normalization module to normalize input images for the VGG-19 model
class Normalize(nn.Module):
    def __init__(self, mean, std):
        # super(Normalization, self).__init__()
        super().__init__()
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, input):
        return (input - self.mean) / self.std # normalization formula

# %% [markdown]
# ## L-BFGS Optimizer
#
# We will use the L-BFGS optimizer to optimize the input image's features to minimize the style/content loss. Notice how this differs from the usual application of optimizing model params.

# %%
def lbfgs_optimizer(input):
    optimizer = torch.optim.LBFGS([input.requires_grad_()]) # records operations applied to the input image
    return optimizer

# %% [markdown]
# ## Preparing the Model

# %% [markdown]
# The paper only uses the first module of the VGG-19 model (features), which contains the convolution and pooling layers to extract the content and style representations. The classifier module in not needed as we are not performing any image classification.

# %% [markdown]
# Note: we will use the model in evaluation mode (.eval()) since it may behave different in evaluation vs. training.

# %%
# see summary of model
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /Users/sophiexie/miniconda3/envs/cv/lib/python3.10/site-packages (1.5.1)

# %%
from torchsummary import summary

# %%
vgg_network = models.vgg19(weights='DEFAULT').features.to(device).eval()
summary(vgg_network, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# ================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.30
# Params size (MB): 76.39
# Estimated Total Size (MB): 315.26
# ----------------------------------------------------------------

# %%
# layers used in the paper to determine content/style representations
content_layers = ['conv_4']
style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

last_layer = 'conv_5'  # Losses stop being calculated after this layer

def get_model_and_losses(network, style_image, content_image, mean=mean, std=std, content_layers=content_layers, style_layers=style_layers):
    network = copy.deepcopy(network)
    normalization = Normalize(mean, std).to(device)

    # make a new sequential model with custom loss/normalization modules
    nst_model = nn.Sequential(normalization)

    style_losses = []
    content_losses = []

    idx = 0
    for layer in network.children():

        # check type of layer
        if isinstance(layer, nn.Conv2d):
            name = 'conv_'
            idx += 1
        elif isinstance(layer, nn.ReLU):
            name = 'relu_'
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_'
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_'
        else:
            raise RuntimeError('Processing invalid layer: {}'.format(layer.__class__.__name__))

        name += str(idx)
        print('adding layer: ', name)
        nst_model.add_module(name, layer)

        if name in content_layers:
            target = nst_model(content_image).detach()
            print('target shape: ', target.size())
            
            content_loss = ContentLoss(target)
            print('content loss: ', content_loss)
            
            nst_model.add_module("content_loss_{}".format(idx), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            target = nst_model(style_image).detach()
            print('target shape: ', target.size())
            
            style_loss = StyleLoss(target)
            print('style loss: ', style_loss)
            
            nst_model.add_module("style_loss_{}".format(idx), style_loss)
            style_losses.append(style_loss)

        if name == last_layer:
            break

    
    # # for i in range(len(new_model) - 1, -1, -1):
    # for i in reversed(len(new_model) - 1):
    #     if isinstance(new_model[i], ContentLoss) or isinstance(new_model[i], StyleLoss):
    #         break  # we don't need the layers after the last content/style loss is computed

    # new_model = new_model[:(i + 1)]

    return nst_model, style_losses, content_losses

# %% [markdown]
# ## Preparing Images

# %%
input_image = content_image.clone()  # we will use the content image as input

plt.figure()
show_image(input_image, title='Input Image')

# %% [markdown]
# ## Apply the Algorithm

# %%
def style_transfer(network, input, content_image, style_image, mean=mean, std=std, 
                   steps=300, style_weight=20000, content_weight=100):
    print('building the model...')
    model, style_losses, content_losses = get_model_and_losses(network, style_image, content_image)

    print('getting the optimizer...')
    optimizer = lbfgs_optimizer(input)

    print('performing style transfer...')
    i = 0
    while i <= steps:

        def closure():
            input_image.data.clamp_(0, 1)  # bound the input tensor

            optimizer.zero_grad()
            model(input_image)
            
            style_loss = 0
            content_loss = 0

            for loss in style_losses:
                style_loss += loss.loss
            for loss in content_losses:
                content_loss += loss.loss

            style_loss *= style_weight
            content_loss *= content_weight

            total_loss = style_loss + content_loss
            print('total loss: ', total_loss)
            
            total_loss.backward()  # Compute the gradient
            print('total loss after back propagation: ', total_loss)
            return total_loss

        print('=============== step {}/{} ==============='.format(i, steps))
        optimizer.step(closure)
        i += 1
        
    input.data.clamp_(0, 1)
    return input

# %%
result = style_transfer(vgg_network, input_image, content_image, style_image)
# Out:
# building the model...
# adding layer:  conv_1
# target shape:  torch.Size([1, 64, 128, 128])
# calculating gram matrix...
# style loss:  StyleLoss()
# adding layer:  relu_1
# adding layer:  conv_2
# calculating gram matrix...
# target shape:  torch.Size([1, 64, 128, 128])
# calculating gram matrix...
# style loss:  StyleLoss()
# adding layer:  relu_2
# adding layer:  pool_2
# adding layer:  conv_3
# calculating gram matrix...
# calculating gram matrix...
# target shape:  torch.Size([1, 128, 64, 64])
# calculating gram matrix...
# style loss:  StyleLoss()
# adding layer:  relu_3
# adding layer:  conv_4
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# target shape:  torch.Size([1, 128, 64, 64])
# content loss:  ContentLoss()
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# target shape:  torch.Size([1, 128, 64, 64])
# calculating gram matrix...
# style loss:  StyleLoss()
# adding layer:  relu_4
# adding layer:  pool_4
# adding layer:  conv_5
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.5757, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.5757, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.5291, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.5291, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.4777, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.4777, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.4268, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.4268, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.3766, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.3766, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.3282, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.3282, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.2820, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.2820, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.2375, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.2375, grad_fn=<AddBackward0>)
# =============== step 6/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.1905, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.1905, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.1452, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.1452, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.1021, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.1021, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.0600, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.0600, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(175.0157, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(175.0157, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.9702, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.9702, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.9280, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.9280, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.8863, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.8863, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.8482, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.8482, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.8099, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.8099, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.7719, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.7719, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.7351, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.7351, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.6977, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.6977, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.6588, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.6588, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.6200, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.6200, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.5815, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.5815, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.5455, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.5455, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.5109, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.5109, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.4760, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.4760, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.4414, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.4414, grad_fn=<AddBackward0>)
# =============== step 7/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.4076, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.4076, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.3763, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.3763, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.3461, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.3461, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.3147, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.3147, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.2834, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.2834, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.2539, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.2539, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.2213, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.2213, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.1919, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.1919, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.1631, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.1631, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.1325, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.1325, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.1017, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.1017, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.0714, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.0714, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.0427, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.0427, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(174.0128, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(174.0128, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.9857, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.9857, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.9580, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.9580, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.9309, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.9309, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.9026, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.9026, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.8774, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.8774, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.8484, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.8484, grad_fn=<AddBackward0>)
# =============== step 8/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.8204, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.8204, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.7921, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.7921, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.7672, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.7672, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.7425, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.7425, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.7141, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.7141, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.6896, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.6896, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.6660, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.6660, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.6411, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.6411, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.6153, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.6153, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.5947, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.5947, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.5712, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.5712, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.5436, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.5436, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.5203, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.5203, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(173.4960, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(173.4960, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# ...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(182.2237, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(182.2237, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(182.5193, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(182.5193, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(182.2083, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(182.2083, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.9727, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.9727, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.8085, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.8085, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.6576, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.6576, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.5115, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.5115, grad_fn=<AddBackward0>)
# =============== step 62/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.4023, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.4023, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.2989, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.2989, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.2125, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.2125, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.1353, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.1353, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.0643, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.0643, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.0057, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.0057, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.9456, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.9456, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.8746, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.8746, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.8290, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.8290, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.7893, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.7893, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.7092, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.7092, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.6473, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.6473, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.6243, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.6243, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.5483, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.5483, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.4636, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.4636, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.3830, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.3830, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.3164, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.3164, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.3242, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.3242, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.2651, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.2651, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.1256, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.1256, grad_fn=<AddBackward0>)
# =============== step 63/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.1530, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.1530, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.0235, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.0235, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.9348, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.9348, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.8650, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.8650, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.7699, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.7699, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.6902, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.6902, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.6457, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.6457, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.5921, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.5921, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.5720, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.5720, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.5164, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.5164, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.4653, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.4653, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.4579, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.4579, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.4108, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.4108, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.3155, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.3155, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.2599, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.2599, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.1782, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.1782, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.1418, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.1418, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.1521, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.1521, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.0882, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.0882, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.0048, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.0048, grad_fn=<AddBackward0>)
# =============== step 64/300 ===============
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.0162, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.0162, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(180.0740, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(180.0740, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(181.7283, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(181.7283, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.6064, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.6064, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.2140, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.2140, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(179.0328, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(179.0328, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.8930, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.8930, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.7718, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.7718, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.6645, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.6645, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.5892, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.5892, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.5189, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.5189, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.4463, grad_fn=<AddBackward0>)
# total loss after back propagation:  tensor(178.4463, grad_fn=<AddBackward0>)
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# calculating gram matrix...
# total loss:  tensor(178.3855, grad_fn=<AddBackward0>)

# %%
plt.figure()
show_image(result, title='Output')
